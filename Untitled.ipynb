# %%
import os
os.add_dll_directory("C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.2/bin")

import matplotlib.pyplot as plt
from PIL import Image

import numpy as np
from numpy import asarray

import tensorflow as tf
import pandas as pd
import random
import time

from tensorflow.keras import Sequential
from tensorflow.keras.layers import ZeroPadding2D, Add,  Activation, RandomFlip, Input, RandomRotation, Conv2D, BatchNormalization, MaxPool2D, Dropout, Flatten, Dense

from sklearn.model_selection import train_test_split

from tensorflow.keras.regularizers import l2

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
directory = 'UTKFace'
ds_len = 0 
for filename in os.listdir(directory):
    if filename.endswith(".jpg"):
        ds_len += 1
    else:
        print(filename)
        
        continue
# Out:
# .ipynb_checkpoints

# %%
def identity(x, num_filter=64):
    x_skip = x

    x = Conv2D(num_filter, (3,3), padding='same')(x)
    x = Dropout(0.2)(x)

    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filter, (3,3), padding='same')(x)
    x = Dropout(0.2)(x)

    x = BatchNormalization(axis=3)(x)

    x = Add()([x, x_skip])
    x = Activation('relu')(x)
    return x

def conv(x, num_filter):
    x_skip = x

    x = Conv2D(num_filter, (3,3), padding='same', strides=(2,2))(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization(axis=3)(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filter, (3,3), padding='same')(x)    
    x = Dropout(0.2)(x)

    x = BatchNormalization(axis=3)(x)

    x_skip = Conv2D(num_filter, (1,1), strides=(2,2))(x_skip)

    x = Add()([x, x_skip])
    x = Activation('relu')(x)
    return x

# %%
def resnet_model():
    input = Input((200,200,3))

    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(input)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    block_layers = [3,4,6,3]
    filter_size=64
    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = identity(x, filter_size)
        else:
            filter_size=filter_size*2
            x = conv(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity(x, filter_size)
    
    x = tf.keras.layers.AveragePooling2D((2,2), padding='same')(x)
    x = Flatten()(x)
    
    # x = Dense(512, activation='relu')(x)
    
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.2)(x)

    x = Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs = input, outputs = x, name="Residual-Network")

    model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def get_subset(set_n):
    found_ind = 0
    df_subset = np.zeros((len(sets[set_n])* 200*200*3), dtype='float32').reshape(-1,200,200,3)
    df_output = np.zeros((len(sets[set_n])), dtype='int8').reshape(len(sets[set_n]), 1)
    for count, filename in enumerate(os.listdir(directory)):
        if count == sets[set_n][found_ind]:
            df_subset[found_ind] = asarray(Image.open(f'UTKFace/{filename}'))
            df_output[found_ind][0] = int(filename.split('_')[1])
            found_ind += 1
            if found_ind == len(sets[set_n]):
                break
    return df_subset, df_output

# %%
genderMode = resnet_model()
genderMode.summary()
# Out:
# Model: "Residual-Network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d_36 (Conv2D)             (None, 100, 100, 64  9472        ['input_2[0][0]']
#                                 )
#
#  dropout_35 (Dropout)           (None, 100, 100, 64  0           ['conv2d_36[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 100, 100, 64  256        ['dropout_35[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 100, 100, 64  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 64)  0           ['activation_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 50, 50, 64)   36928       ['max_pooling2d_1[0][0]']
#
#  dropout_36 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_37[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 50, 50, 64)  256         ['dropout_36[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 50, 50, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 50, 50, 64)   36928       ['activation_34[0][0]']
#
#  dropout_37 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_38[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 50, 50, 64)  256         ['dropout_37[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 50, 50, 64)   0           ['batch_normalization_35[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  activation_35 (Activation)     (None, 50, 50, 64)   0           ['add_16[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 50, 50, 64)   36928       ['activation_35[0][0]']
#
#  dropout_38 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_39[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 50, 50, 64)  256         ['dropout_38[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 50, 50, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 50, 50, 64)   36928       ['activation_36[0][0]']
#
#  dropout_39 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_40[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 50, 50, 64)  256         ['dropout_39[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 50, 50, 64)   0           ['batch_normalization_37[0][0]',
#                                                                   'activation_35[0][0]']
#
#  activation_37 (Activation)     (None, 50, 50, 64)   0           ['add_17[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 50, 50, 64)   36928       ['activation_37[0][0]']
#
#  dropout_40 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_41[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 50, 50, 64)  256         ['dropout_40[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 50, 50, 64)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 50, 50, 64)   36928       ['activation_38[0][0]']
#
#  dropout_41 (Dropout)           (None, 50, 50, 64)   0           ['conv2d_42[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 50, 50, 64)  256         ['dropout_41[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 50, 50, 64)   0           ['batch_normalization_39[0][0]',
#                                                                   'activation_37[0][0]']
#
#  activation_39 (Activation)     (None, 50, 50, 64)   0           ['add_18[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 25, 25, 128)  73856       ['activation_39[0][0]']
#
#  dropout_42 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_43[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 25, 25, 128)  512        ['dropout_42[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 25, 25, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_40[0][0]']
#
#  dropout_43 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_44[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 25, 25, 128)  512        ['dropout_43[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 25, 25, 128)  8320        ['activation_39[0][0]']
#
#  add_19 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_41[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  activation_41 (Activation)     (None, 25, 25, 128)  0           ['add_19[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_41[0][0]']
#
#  dropout_44 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 25, 25, 128)  512        ['dropout_44[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 25, 25, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_42[0][0]']
#
#  dropout_45 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_47[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 25, 25, 128)  512        ['dropout_45[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_43[0][0]',
#                                                                   'activation_41[0][0]']
#
#  activation_43 (Activation)     (None, 25, 25, 128)  0           ['add_20[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_43[0][0]']
#
#  dropout_46 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_48[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 25, 25, 128)  512        ['dropout_46[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 25, 25, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_44[0][0]']
#
#  dropout_47 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_49[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 25, 25, 128)  512        ['dropout_47[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_45[0][0]',
#                                                                   'activation_43[0][0]']
#
#  activation_45 (Activation)     (None, 25, 25, 128)  0           ['add_21[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_45[0][0]']
#
#  dropout_48 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_50[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 25, 25, 128)  512        ['dropout_48[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 25, 25, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 25, 25, 128)  147584      ['activation_46[0][0]']
#
#  dropout_49 (Dropout)           (None, 25, 25, 128)  0           ['conv2d_51[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 25, 25, 128)  512        ['dropout_49[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 25, 25, 128)  0           ['batch_normalization_47[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_47 (Activation)     (None, 25, 25, 128)  0           ['add_22[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 13, 13, 256)  295168      ['activation_47[0][0]']
#
#  dropout_50 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 13, 13, 256)  1024       ['dropout_50[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_48[0][0]']
#
#  dropout_51 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_53[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 13, 13, 256)  1024       ['dropout_51[0][0]']
#  ormalization)
#
#  conv2d_54 (Conv2D)             (None, 13, 13, 256)  33024       ['activation_47[0][0]']
#
#  add_23 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_49[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  activation_49 (Activation)     (None, 13, 13, 256)  0           ['add_23[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_49[0][0]']
#
#  dropout_52 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_55[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 13, 13, 256)  1024       ['dropout_52[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_50[0][0]']
#
#  dropout_53 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_56[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 13, 13, 256)  1024       ['dropout_53[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_51[0][0]',
#                                                                   'activation_49[0][0]']
#
#  activation_51 (Activation)     (None, 13, 13, 256)  0           ['add_24[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_51[0][0]']
#
#  dropout_54 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_57[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 13, 13, 256)  1024       ['dropout_54[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_52[0][0]']
#
#  dropout_55 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_58[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 13, 13, 256)  1024       ['dropout_55[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_53[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_53 (Activation)     (None, 13, 13, 256)  0           ['add_25[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_53[0][0]']
#
#  dropout_56 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_59[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 13, 13, 256)  1024       ['dropout_56[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_54[0][0]']
#
#  dropout_57 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_60[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 13, 13, 256)  1024       ['dropout_57[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_55[0][0]',
#                                                                   'activation_53[0][0]']
#
#  activation_55 (Activation)     (None, 13, 13, 256)  0           ['add_26[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_55[0][0]']
#
#  dropout_58 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_61[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 13, 13, 256)  1024       ['dropout_58[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_56[0][0]']
#
#  dropout_59 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_62[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 13, 13, 256)  1024       ['dropout_59[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_57[0][0]',
#                                                                   'activation_55[0][0]']
#
#  activation_57 (Activation)     (None, 13, 13, 256)  0           ['add_27[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_57[0][0]']
#
#  dropout_60 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_63[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 13, 13, 256)  1024       ['dropout_60[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 13, 13, 256)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 13, 13, 256)  590080      ['activation_58[0][0]']
#
#  dropout_61 (Dropout)           (None, 13, 13, 256)  0           ['conv2d_64[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 13, 13, 256)  1024       ['dropout_61[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 13, 13, 256)  0           ['batch_normalization_59[0][0]',
#                                                                   'activation_57[0][0]']
#
#  activation_59 (Activation)     (None, 13, 13, 256)  0           ['add_28[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 7, 7, 512)    1180160     ['activation_59[0][0]']
#
#  dropout_62 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_65[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 512)   2048        ['dropout_62[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_60[0][0]']
#
#  dropout_63 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_66[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 512)   2048        ['dropout_63[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 7, 7, 512)    131584      ['activation_59[0][0]']
#
#  add_29 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_61[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  activation_61 (Activation)     (None, 7, 7, 512)    0           ['add_29[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_61[0][0]']
#
#  dropout_64 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_68[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 512)   2048        ['dropout_64[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_62[0][0]']
#
#  dropout_65 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_69[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 7, 7, 512)   2048        ['dropout_65[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_63[0][0]',
#                                                                   'activation_61[0][0]']
#
#  activation_63 (Activation)     (None, 7, 7, 512)    0           ['add_30[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_63[0][0]']
#
#  dropout_66 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_70[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 7, 7, 512)   2048        ['dropout_66[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_64[0][0]']
#
#  dropout_67 (Dropout)           (None, 7, 7, 512)    0           ['conv2d_71[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 7, 7, 512)   2048        ['dropout_67[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_65[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_65 (Activation)     (None, 7, 7, 512)    0           ['add_31[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 512)   0           ['activation_65[0][0]']
#  oling2D)
#
#  flatten_1 (Flatten)            (None, 8192)         0           ['average_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 256)          2097408     ['flatten_1[0][0]']
#
#  dropout_68 (Dropout)           (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          65792       ['dropout_68[0][0]']
#
#  dropout_69 (Dropout)           (None, 256)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            257         ['dropout_69[0][0]']
#
# ==================================================================================================
# Total params: 23,470,081
# Trainable params: 23,454,849
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
# genderMode.load_weights('./checkpoints/gender_check_Jan_10_12_11')

# %%
random.seed(time.time())
train_times = 1
numSets = 50

for train in range(train_times):
    allNums = random.sample(range(ds_len), ds_len)
    sets = [0]*numSets
    for i in range(numSets):
        sets[i] = sorted(allNums[((ds_len//numSets) * i) : ((ds_len//numSets) * (i+1))])

    for i in range(numSets):
        X, y = get_subset(i)
        trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.2)
        hist = genderMode.fit(trainX, trainY, epochs=5, batch_size=32, validation_data=(testX, testY), verbose=0)
        print('model accuracy {}-{}: {}'.format(train, i, hist.history['accuracy'][-1]))
        genderMode.save_weights('./checkpoints/gender_check_Jan_10_12_11')

# %%
def sigmoid_model():
    model = Sequential([
        Input((200,200,3)),

        RandomFlip("horizontal_and_vertical"),
        RandomRotation(0.2),
        
        Conv2D(64, (3,3), activation='relu'),
        MaxPool2D(pool_size=(2,2)),
        BatchNormalization(),
        Dropout(0.25),

        Conv2D(128, (3,3), activation='relu'),
        MaxPool2D(pool_size=(2,2)),
        BatchNormalization(),
        Dropout(0.25),

        Conv2D(256, (3,3), activation='relu'),
        MaxPool2D(pool_size=(2,2)),
        BatchNormalization(),
        Dropout(0.25),

        Conv2D(512, (3,3), activation='relu'),
        MaxPool2D(pool_size=(2,2)),
        BatchNormalization(),
        Dropout(0.25),

        Conv2D(1024, (3,3), activation='relu'),
        MaxPool2D(pool_size=(2,2)),
        BatchNormalization(),
        Dropout(0.25),

        Flatten(),

        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),

        Dense(1, activation='sigmoid')                           
    ])
    model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['accuracy'])
    return model

# %%
sig = sigmoid_model()
sig.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip (RandomFlip)    (None, 200, 200, 3)       0
#
#  random_rotation (RandomRota  (None, 200, 200, 3)      0
#  tion)
#
#  conv2d_72 (Conv2D)          (None, 198, 198, 64)      1792
#
#  max_pooling2d_2 (MaxPooling  (None, 99, 99, 64)       0
#  2D)
#
#  batch_normalization_66 (Bat  (None, 99, 99, 64)       256
#  chNormalization)
#
#  dropout_70 (Dropout)        (None, 99, 99, 64)        0
#
#  conv2d_73 (Conv2D)          (None, 97, 97, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 128)      0
#  2D)
#
#  batch_normalization_67 (Bat  (None, 48, 48, 128)      512
#  chNormalization)
#
#  dropout_71 (Dropout)        (None, 48, 48, 128)       0
#
#  conv2d_74 (Conv2D)          (None, 46, 46, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 23, 23, 256)      0
#  2D)
#
#  batch_normalization_68 (Bat  (None, 23, 23, 256)      1024
#  chNormalization)
#
#  dropout_72 (Dropout)        (None, 23, 23, 256)       0
#
#  conv2d_75 (Conv2D)          (None, 21, 21, 512)       1180160
#
#  max_pooling2d_5 (MaxPooling  (None, 10, 10, 512)      0
#  2D)
#
#  batch_normalization_69 (Bat  (None, 10, 10, 512)      2048
#  chNormalization)
#
#  dropout_73 (Dropout)        (None, 10, 10, 512)       0
#
#  conv2d_76 (Conv2D)          (None, 8, 8, 1024)        4719616
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 1024)       0
#  2D)
#
#  batch_normalization_70 (Bat  (None, 4, 4, 1024)       4096
#  chNormalization)
#
#  dropout_74 (Dropout)        (None, 4, 4, 1024)        0
#
#  flatten_2 (Flatten)         (None, 16384)             0
#
#  dense_6 (Dense)             (None, 128)               2097280
#
#  batch_normalization_71 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_75 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  batch_normalization_72 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_76 (Dropout)        (None, 128)               0
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  batch_normalization_73 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_77 (Dropout)        (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,410,497
# Trainable params: 8,405,761
# Non-trainable params: 4,736
# _________________________________________________________________
